# %% [markdown]
# ___
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/d/db/Logo_ITESO_normal.jpg" width="150" height="100" />
#
#
# # SEGUNDO EXAMEN PARCIAL
# # MODELO NO LINEAL PARA PRONÓSTICOS
#
# ## Examen Tema 2
# ## Nombre:m José de Jesús Carbajal Castellanos
#
# ## Fecha: 25 de marzo del 2025
#
# ## Por: Oscar David Jaramillo Z.

# %% [markdown]
# # **Examen de Series de Tiempo con Redes Neuronales**
#
# ## **Instrucciones Generales**
#
# En este examen trabajarás con dos conjuntos de datos diferentes: **univariado** y **multivariado**. Los datos univariados se encuentran en la carpeta `univariate`, y los datos multivariados en la carpeta `multivariate`.
#
# Deberás implementar los modelos de redes neuronales **MLP**, **CNN**, **LSTM** y **CNN-LSTM** para realizar predicciones en ambos conjuntos de datos.
#
# Deberás justificar tus decisiones y documentar adecuadamente tu código y procedimientos.
#
#
#
# ---
#
# ## **Conjunto de Datos**
#
# ### **1. Datos Univariados**
#
# - **Archivos:**
#   - `Hourly-train.csv`: Datos históricos de series de tiempo horarias del conjunto M4.
#   - `m4_info.csv`: Metadatos que incluyen información como la frecuencia de medición, horizonte de predicción y fecha de inicio.
# - **Descripción:**
#   - Cada fila de `Hourly-train.csv` representa una serie de tiempo, y cada columna representa un paso de tiempo.
#   - El archivo `m4_info.csv` contiene información adicional como:
#     - **Frecuencia:** Frecuencia de las mediciones (anual, trimestral, mensual, semanal, diaria u horaria).
#     - **Horizonte:** Número de pasos a predecir para cada serie.
#     - **Fecha de inicio:** Fecha de la primera medición.
#     -  Un ejemplo del contenido de este archivo se muestra a continuación:
#
# | M4id   | category   |   Frequency |   Horizon | SP     | StartingDate   |
# |:-------|:-----------|------------:|----------:|:-------|:---------------|
# | Y1     | Macro      |           1 |         6 | Yearly | 01-01-79 12:00 |
#
#    Lo que interpretamos como que la Serie de tiempo $Y1$ tiene una frecuencia anual entre mediciones y las mediciones empiezan el `01-01-79 12:00`. El horizonte que debe predecir esta serie de tiempo es 6 pasos al futuro.
# Estos datos serán relevantes para poder generar el índice de fechas y también que cada modelo debe de generar una predicción conforme al `Horizont` especificado.
# - **Series asignadas por estudiante:** Cada estudiante deberá generar predicciones para las siguientes series de datos:
#
# | data                                     | Student                             |
# |:-----------------------------------------|:------------------------------------|
# | ['H404', 'H275', 'H64', 'H228', 'H38']   | CARBAJAL CASTELLANOS, JOSE DE JESUS |
# ---
#
# ### **2. Datos Multivariados**
#
# - **Archivo:** `Daily Demand Forecasting Orders`.
# - **Descripción:**
#   - Contiene 60 filas (días) y 13 columnas (atributos).
#   - Objetivo: Predecir el total de pedidos diarios (`Target`) utilizando los demás atributos como variables predictoras.
# - **Atributos:**
#   - Los atributos en este conjunto de datos son los siguientes:
#
#         Week of the month: La semana del mes (1 a 5).
#         Day of the week (Monday to Friday): El día de la semana (2 a 6).
#         Non-urgent order: El número de pedidos no urgentes.
#         Urgent order: El número de pedidos urgentes.
#         Order type A: El número de pedidos de tipo A.
#         Order type B: El número de pedidos de tipo B.
#         Order type C: El número de pedidos de tipo C.
#         Fiscal sector orders: El número de pedidos del sector fiscal.
#         Orders from the traffic controller sector: El número de pedidos del sector controlador de tráfico.
#         Banking orders (1): El número de pedidos bancarios (1).
#         Banking orders (2): El número de pedidos bancarios (2).
#         Banking orders (3): El número de pedidos bancarios (3).
#         Target (Total orders): El total de pedidos (objetivo).
#
# ---
#
# ## **Tareas y Requisitos**
#
# Para ambos conjuntos de datos (univariado y multivariado), realiza las siguientes tareas para cada red neuronal (MLP, CNN, LSTM y CNN-LSTM):
#
# ### **1. Análisis de Datos (20%)**
#
# - **Carga los datos** y realiza una visualización clara de las series asignadas o los atributos del conjunto de datos.
# - Realiza las transformaciones o preprocesamiento que consideres necesarios.
# - Justifica tus decisiones de preprocesamiento y explica cualquier análisis relevante que realices.
#
# ### **2. División de Datos (10%)**
#
# - Divide los datos en conjuntos de entrenamiento, validación y prueba.
# - **Univariado:**
#   - Crea índices de tiempo usando el archivo `m4_info.csv`.
#   - Genera el horizonte de predicción basado en la columna `Horizon` asignada a cada serie.
# - **Multivariado:**
#   - Divide las filas en un 70%-15%-15% (entrenamiento, validación, prueba).
#
# ### **3. Creación de Modelos (30%)**
#
# - **Diseña las redes neuronales** utilizando MLP, CNN, LSTM y CNN-LSTM:
#   - Implementa al menos **tres arquitecturas diferentes** para cada modelo.
#   - Selecciona la estructura que arroje mejores resultados.
# - Justifica la elección de las capas ocultas, funciones de activación, optimizadores y otras configuraciones.
# - Discute los resultados obtenidos y menciona posibles formas de mejorar el rendimiento.
#
# ### **4. Evaluación del Modelo (20%)**
#
# - Evalúa los modelos en el conjunto de prueba.
# - Compara los pronósticos con los valores reales:
#   - Si realizaste alguna transformación en los datos (como normalización), revierte las transformaciones antes de la comparación.
# - Mide la precisión del modelo utilizando métricas adecuadas como:
#   - **RMSE, MAE, MAPE, o R².**
#
# ### **5. Optimización con Optuna (15%)**
#
# - Implementa **Optuna** para ajustar los hiperparámetros del modelo:
#   - Ajusta al menos los siguientes hiperparámetros:
#     - Número de capas, número de unidades, tasa de aprendizaje, tipo de optimizador y funciones de activación.
#   - Evalúa el modelo optimizado en el conjunto de prueba.
# - Documenta los cambios en el rendimiento antes y después de la optimización.
#
# ---
#
# ## **Formato y Presentación (5%)**
#
# 1. **Estructura del Trabajo:**
#    - Introducción a los datos y al modelo.
#    - Explicación del preprocesamiento realizado.
#    - Descripción y justificación de las arquitecturas probadas.
#    - Análisis de resultados antes y después de la optimización.
# 2. **Código:**
#    - Bien comentado y estructurado.
#    - Justifica cada paso del código con explicaciones claras.
# 3. **Gráficos:**
#    - Incluye gráficos de las series de tiempo, visualización de errores y desempeño del modelo.
# 4. **Conclusión:**
#    - Resume tus hallazgos, dificultades encontradas y posibles mejoras.
#
# ---
#
# **¡Éxito con tu examen!**

# %% [markdown]
# # Datos univariados
# - se encuentran en los archivos con los nombres de cada serie

# %% [markdown]
# # Datos multivariados

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import optuna

from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import (
    Dense, Dropout, Conv1D, MaxPooling1D, Flatten,
    LSTM, Bidirectional, TimeDistributed, GlobalAveragePooling1D,
    BatchNormalization, LeakyReLU, GRU, SpatialDropout1D
)

from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# 2025-04-01 22:35:24.845488: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743568524.934294 1467461 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743568524.959660 1467461 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-01 22:35:25.157110: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# We load the dataset
df = pd.read_csv('multivariate/Daily_Demand_Forecasting_Orders.csv', sep=';')
df.head()
# Out:
#    Week of the month (first week, second, third, fourth or fifth week  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  2
# 4                                                  2
#
#    Day of the week (Monday to Friday)  Non-urgent order  Urgent order  \
# 0                                   4           316.307       223.270
# 1                                   5           128.633        96.042
# 2                                   6            43.651        84.375
# 3                                   2           171.297       127.667
# 4                                   3            90.532       113.526
#
#    Order type A  Order type B  Order type C  Fiscal sector orders  \
# 0        61.543       175.586       302.448                 0.000
# 1        38.058        56.037       130.580                 0.000
# ...

# %%
# We'll rename the columns for easier handling
df.rename(columns={
    'Week of the month (first week, second, third, fourth or fifth week': 'Week_of_Month',
    'Day of the week (Monday to Friday)': 'Day_of_Week',
    'Non-urgent order': 'Non_Urgent_Order',
    'Urgent order': 'Urgent_Order',
    'Order type A': 'Order_Type_A',
    'Order type B': 'Order_Type_B',
    'Order type C': 'Order_Type_C',
    'Fiscal sector orders': 'Fiscal_Sector_Orders',
    'Orders from the traffic controller sector': 'Traffic_Controller_Orders',
    'Banking orders (1)': 'Banking_Orders_1',
    'Banking orders (2)': 'Banking_Orders_2',
    'Banking orders (3)': 'Banking_Orders_3',
    'Target (Total orders)': 'Total_Orders'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['Week_of_Month', 'Day_of_Week', 'Non_Urgent_Order', 'Urgent_Order',
#        'Order_Type_A', 'Order_Type_B', 'Order_Type_C', 'Fiscal_Sector_Orders',
#        'Traffic_Controller_Orders', 'Banking_Orders_1', 'Banking_Orders_2',
#        'Banking_Orders_3', 'Total_Orders'],
#       dtype='object')

# %%
# Train set (70%)
train = df.iloc[:int(len(df) * 0.7), :]

# Val set (15%)
val = df.iloc[int(len(df) * 0.7):int(len(df) * 0.85), :]

# Test set (15%)
test = df.iloc[int(len(df) * 0.85):, :]

col = "Total_Orders"

plt.figure(figsize=(12, 6))

plt.plot(train.index, train[col], color="blue", label="Train (70%)")
plt.plot(val.index, val[col], color="orange", label="Val (15%)")
plt.plot(test.index, test[col], color="red", label="Test (15%)")

plt.xlabel("Fecha")
plt.ylabel(col)
plt.legend()
plt.title(f"Target var set split")
plt.show()

# %%
# Split the multivariate data in steps
def split_multivariate_sequence_m_step(sequence: np.ndarray, n_steps_in: int, n_steps_out: int=1):
    """
    Divide una secuencia multivariada en muestras
    :param sequence: Array de numpy con la secuencia
    :param n_steps_in: Número de pasos de entrada
    :param n_steps_out: Número de pasos de salida
    :return: Devuelve dos arrays de numpy con las muestras de entrada y salida
    """
    X, y = list(), list()
    for i in range(len(sequence)):
        # encontrar el final de este patrón
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out - 1

        # comprobar si estamos más allá de la secuencia
        if out_end_ix > len(sequence):
            break
        # reunir partes de entrada y salida del patrón
        seq_x, seq_y = sequence[i:end_ix, :-1], sequence[end_ix - 1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

n_steps_in, n_steps_out = 6, 1

X_train, y_train = split_multivariate_sequence_m_step(train.values, n_steps_in, n_steps_out)

# %%
#split the data and show shapes
n_steps_in, n_steps_out = 6, 1

X_train, y_train = split_multivariate_sequence_m_step(train.values, n_steps_in, n_steps_out)
X_val, y_val = split_multivariate_sequence_m_step(val.values, n_steps_in, n_steps_out)
X_test, y_test = split_multivariate_sequence_m_step(test.values, n_steps_in, n_steps_out)

print('Train split shape', X_train.shape, y_train.shape)
print('Val split shape', X_val.shape, y_val.shape)
print('Test split shape', X_test.shape, y_test.shape)
# Out:
# Train split shape (37, 6, 12) (37, 1)
# Val split shape (4, 6, 12) (4, 1)
# Test split shape (4, 6, 12) (4, 1)

# %%
random_state = 42
np.random.seed(random_state)
tf.random.set_seed(random_state)

# Define Learning rate to experiment
learning_rate = 0.001

# Extract steps and features
n_steps = X_train.shape[1] 
n_features = X_train.shape[2]

###############################################################

# MLP Models

# frist arch from 96 to 24, 4 Dense with relu and one batchnormalization
mlp_model_1 = Sequential([
    Flatten(input_shape=(n_steps, n_features)),
    Dense(96, activation='relu'),
    Dense(48, activation='relu'),
    BatchNormalization(),
    Dense(24, activation='relu'),
    Dense(1)
], name='MLP_Model_1')

# Seccond arch from 160 to 40, 3 Dense 2 Dropout layers with 0.25% 
mlp_model_2 = Sequential([
    Flatten(input_shape=(n_steps, n_features)),
    Dense(160, activation='relu'),
    Dropout(0.25),
    Dense(80, activation='relu'),
    Dropout(0.25),
    Dense(40, activation='relu'),
    Dense(1)
], name='MLP_Model_2')

# Third arch fron 192 to 48, with 3 Dense Leaky relu with alpha 0.1 to allow really small negatives
mlp_model_3 = Sequential([
    Flatten(input_shape=(n_steps, n_features)),
    Dense(192, activation=LeakyReLU(alpha=0.1)),
    BatchNormalization(),
    Dense(96, activation=LeakyReLU(alpha=0.1)),
    Dense(48, activation=LeakyReLU(alpha=0.1)),
    Dense(1)
], name='MLP_Model_3')

# CNN Models

#First arch conv 1d filter with 48 neurons, max pooling by half, and Dense with 64 neurons
cnn_model_1 = Sequential([
    Conv1D(48, 2, activation='relu', padding='same', input_shape=(n_steps, n_features)),
    MaxPooling1D(2),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(1)
], name='CNN_Model_1')

#Seccond arch, two conv 1D layers with 72 and 144 neurons with leaky relu and max pooling, dense and dropout with 25%
cnn_model_2 = Sequential([
    Conv1D(72, 3, activation=LeakyReLU(alpha=0.1), padding='same', input_shape=(n_steps, n_features)),
    MaxPooling1D(2),
    Conv1D(144, 2, activation=LeakyReLU(alpha=0.1), padding='same'),
    MaxPooling1D(2),
    Flatten(),
    Dense(80, activation=LeakyReLU(alpha=0.1)),
    Dropout(0.25),
    Dense(1)
], name='CNN_Model_2')

# Third arch two conv1d, global average pooling (to get the mean of the secuence) and batchnormmalization
cnn_model_3 = Sequential([
    Conv1D(56, 2, activation='relu', padding='same', input_shape=(n_steps, n_features)),
    BatchNormalization(),
    Conv1D(112, 2, activation='relu', padding='same'),
    GlobalAveragePooling1D(),
    Dense(56, activation='relu'),
    Dense(1)
], name='CNN_Model_3')

# LSTM Models

# First arch
# Stacked Lstm from 40 to 24 neurons with tanh and dropout
lstm_model_1 = Sequential([
    LSTM(40, activation='tanh', return_sequences=True, input_shape=(n_steps, n_features)),
    LSTM(24, activation='tanh'),
    Dropout(0.25),
    Dense(1)
], name='LSTM_Model_1')

# Seccond arch
#Stacked lstm with SpatialDropout (drops entire feature maps instead of only neurons) and a dense layer
lstm_model_2 = Sequential([
    LSTM(72, activation='tanh', return_sequences=True, input_shape=(n_steps, n_features)),
    SpatialDropout1D(0.15),
    LSTM(36, activation='tanh'),
    Dense(16, activation='relu'),
    Dense(1)
], name='LSTM_Model_2')

#Third arch
# Bidirectional GRU with dropout and batchnormalization
lstm_model_3 = Sequential([
    Bidirectional(GRU(56, activation='tanh', return_sequences=True), input_shape=(n_steps, n_features)),
    BatchNormalization(),
    Dense(40, activation='relu'),
    Dropout(0.2),
    Dense(1)
], name='LSTM_Model_3')

# CNN-LSTM

#First arch
# one conv filter and maxpooling, also using Timedistributed dense for the lstm
#Leaky relu cause it has been showing good performance on other models
cnnlstm_model_1 = Sequential([
    Conv1D(72, 2, activation=LeakyReLU(alpha=0.1), padding='same', input_shape=(n_steps, n_features)),
    MaxPooling1D(2),
    TimeDistributed(Dense(30, activation=LeakyReLU(alpha=0.1))),
    LSTM(45, activation='tanh'),
    Dense(1)
], name='CNN_LSTM_Model_1')

#Seccond arch
# two conv filter with normal relu, batch normalization and TimeDistributed for lstm
cnnlstm_model_2 = Sequential([
    Conv1D(56, 2, activation='relu', padding='same', input_shape=(n_steps, n_features)),
    MaxPooling1D(2),
    Conv1D(112, 2, activation='relu', padding='same'),
    BatchNormalization(),
    TimeDistributed(Dense(40, activation='relu')),
    LSTM(50, activation='tanh'),
    Dense(1)
], name='CNN_LSTM_Model_2')

# third arch
# Conv layer, Spatial dropout and maxpooling with timedistributed
cnnlstm_model_3 = Sequential([
    Conv1D(80, 3, activation=LeakyReLU(alpha=0.1), padding='same', input_shape=(n_steps, n_features)),
    SpatialDropout1D(0.1),
    MaxPooling1D(2),
    TimeDistributed(Dense(36, activation=LeakyReLU(alpha=0.1))),
    Bidirectional(GRU(48, activation='tanh')),
    Dense(1)
], name='CNN_LSTM_Model_3')

# get the models for training
models = [
    mlp_model_1, mlp_model_2, mlp_model_3,
    cnn_model_1, cnn_model_2, cnn_model_3,
    lstm_model_1, lstm_model_2, lstm_model_3,
    cnnlstm_model_1, cnnlstm_model_2, cnnlstm_model_3
]

#this learning rate schedule reduces lr after 20 epochs of not improoving
lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=20,
    min_lr=1e-6,
    verbose=1
)

#Early stopping as in the univariate example, 20 epochs as patience
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=20,
    restore_best_weights=True,
    verbose=1
)

# compile all the models
for model in models:
    model.compile(
        optimizer=Adam(learning_rate=learning_rate, clipnorm=1.0),
        loss='mse',
        metrics=['mae']
    )

# Train and evaluate each model
def train_and_evaluate_model(model, X_train, y_train, X_val, y_val, X_test, y_test, epochs=200, batch_size=64):
    print(f'\nTraining {model.name}...')
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[lr_scheduler, early_stopping],
        verbose=1
    )
    
    # Eval on the test set
    test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
    print(f'{model.name} - Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}')
    
    return history, test_loss, test_mae

# train and eval each model in the list
results = {}
for model in models:
    history, test_loss, test_mae = train_and_evaluate_model(
        model, X_train, y_train, X_val, y_val, X_test, y_test
    )
    results[model.name] = {
        'history': history,
        'test_loss': test_loss,
        'test_mae': test_mae
    }

# Print results
print("\n===== MODEL PERFORMANCE SUMMARY =====")
for model_name in results:
    print(f"{model_name}: Test MAE = {results[model_name]['test_mae']:.4f}")

# # Find the best model based on the test MAE
best_model_name = min(results, key=lambda x: results[x]['test_mae'])
print(f"\nBest model: {best_model_name} with Test MAE = {results[best_model_name]['test_mae']:.4f}")
# Out:
# /home/pepechuy/.local/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-04-01 22:35:29.973614: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/pepechuy/.local/lib/python3.12/site-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /home/pepechuy/.local/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...

# %%
# get the best model from the previous experiment
best_model_name = min(results, key=lambda x: results[x]['test_mae'])
best_model = next(model for model in models if model.name == best_model_name)

# Create a copy of the test data for sequential predictions
test_data = test.copy()
predictions = []

for i in range(len(test_data) - n_steps_in):
    # Get the input window
    window = test_data.iloc[i:i+n_steps_in, :-1].values.reshape(1, n_steps_in, n_features)
    
    # Make prediction
    pred = best_model.predict(window, verbose=0)[0][0]
    predictions.append(pred)

# Compare with actual values starting from n_steps_in
actual_values = test_data['Total_Orders'].iloc[n_steps_in:].values

# Set these as your flat arrays for plotting
y_test_flat = actual_values
y_pred_flat = np.array(predictions)

# Calculate metrics
mse = mean_squared_error(y_test_flat, y_pred_flat)
mae = mean_absolute_error(y_test_flat, y_pred_flat)
rmse = np.sqrt(mse)

# Create sequence for the x axis
x = np.arange(len(y_test_flat))

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
plt.plot(x, y_test_flat, label='Actual Values', color='blue', linewidth=2)
plt.plot(x, y_pred_flat, label='Predicted Values', color='red', linewidth=1.5, alpha=0.8)

# Scatterplot
plt.scatter(x, y_test_flat, color='blue', s=10, alpha=0.5)
plt.scatter(x, y_pred_flat, color='red', s=10, alpha=0.5)

# Highlight discrepancies with vertical lines
for i in x:
    plt.plot([i, i], [y_test_flat[i], y_pred_flat[i]], 'gray', alpha=0.3, linestyle='--')

# Add labels and title
plt.title(f'Predictions vs Actual Values using {best_model_name}', fontsize=16)
plt.xlabel('Test Sample Index', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Add metrics
plt.figtext(0.15, 0.8, f'RMSE: {rmse:.4f}\nMAE: {mae:.4f}', 
            bbox=dict(facecolor='white', alpha=0.8, boxstyle='round,pad=0.5'))

plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

print(f"\nSample of Predictions vs Actual Values for {best_model_name}:")
print("-" * 60)
print(f"{'Index':>8} | {'Actual':>12} | {'Predicted':>12} | {'Difference':>12}")
print("-" * 60)

n_samples = min(20, len(y_test_flat))
for i in range(n_samples):
    actual = y_test_flat[i]
    pred = y_pred_flat[i]
    diff = actual - pred
    print(f"{i:8d} | {actual:12.4f} | {pred:12.4f} | {diff:12.4f}")

plt.tight_layout()
plt.show()
# Out:
# Sample of Predictions vs Actual Values for MLP_Model_3:
# ------------------------------------------------------------
#    Index |       Actual |    Predicted |   Difference
# ------------------------------------------------------------
#        0 |     303.4470 |     289.7644 |      13.6826
#        1 |     304.9500 |     225.0085 |      79.9415
#        2 |     331.9000 |     418.3319 |     -86.4319

# %% [markdown]
# # Optuna optimization

# %%
# Define the objective function, and give parameters to optimize layers, neurons, lr, optimizer and activation functions
def objective(trial):
    n_layers = trial.suggest_int('n_layers', 1, 5)
    units = [trial.suggest_int(f'units_{i}', 32, 256) for i in range(n_layers)]
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
    optimizer_name = trial.suggest_categorical('optimizer', ['adam', 'sgd'])
    activation_function = trial.suggest_categorical('activation_function', ['relu', 'tanh', 'sigmoid'])

    model = Sequential()
    model.add(Flatten(input_shape=(n_steps, n_features)))

    for unit in units:
        model.add(Dense(unit, activation=activation_function))
        model.add(BatchNormalization())

    model.add(Dense(1))

    optimizer = Adam(learning_rate=learning_rate) if optimizer_name == 'adam' else SGD(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])

    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200, batch_size=64, callbacks=[early_stopping], verbose=0)

    test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
    return test_mae

# Create a study and optimize for 50 trials
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# get the best trial
best_trial = study.best_trial
print(f'Best trial: {best_trial.number}')
print(f'Best MAE: {best_trial.value}')
print(f'Best hyperparameters: {best_trial.params}')

# Train the model with the hyperparams of the best trial
best_params = best_trial.params
n_layers = best_params['n_layers']
units = [best_params[f'units_{i}'] for i in range(n_layers)]
learning_rate = best_params['learning_rate']
optimizer_name = best_params['optimizer']
activation_function = best_params['activation_function']

# build and train the best model
best_model = Sequential()
best_model.add(Flatten(input_shape=(n_steps, n_features)))

for unit in units:
    best_model.add(Dense(unit, activation=activation_function))
    best_model.add(BatchNormalization())

best_model.add(Dense(1))

optimizer = Adam(learning_rate=learning_rate) if optimizer_name == 'adam' else SGD(learning_rate=learning_rate)
best_model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
# After training the best model from Optuna
best_model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200, batch_size=64, verbose=1)

# Create a copy of the test data for sequential predictions
test_data = test.copy()
predictions = []

for i in range(len(test_data) - n_steps_in):
    # Get the input window
    window = test_data.iloc[i:i+n_steps_in, :-1].values.reshape(1, n_steps_in, n_features)
    
    # Make prediction
    pred = best_model.predict(window, verbose=0)[0][0]
    predictions.append(pred)

# Compare with actual values starting from n_steps_in
actual_values = test_data['Total_Orders'].iloc[n_steps_in:].values

# Set these as your flat arrays for plotting
y_test_flat = actual_values
y_pred_flat = np.array(predictions)

# Evaluate
mse = mean_squared_error(y_test_flat, y_pred_flat)
mae = mean_absolute_error(y_test_flat, y_pred_flat)
rmse = np.sqrt(mse)

# Plot the same graph than the previous experiment
plt.figure(figsize=(12, 6))
x = np.arange(len(y_test_flat))
plt.plot(x, y_test_flat, label='Actual Values', color='blue', linewidth=2)
plt.plot(x, y_pred_flat, label='Predicted Values', color='red', linewidth=1.5, alpha=0.8)
plt.scatter(x, y_test_flat, color='blue', s=10, alpha=0.5)
plt.scatter(x, y_pred_flat, color='red', s=10, alpha=0.5)

for i in x:
    plt.plot([i, i], [y_test_flat[i], y_pred_flat[i]], 'gray', alpha=0.3, linestyle='--')

plt.title(f'Predictions vs Actual Values using Best Model', fontsize=16)
plt.xlabel('Test Sample Index', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.figtext(0.15, 0.8, f'RMSE: {rmse:.4f}\nMAE: {mae:.4f}', bbox=dict(facecolor='white', alpha=0.8, boxstyle='round,pad=0.5'))
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# predictions vs actual values
print(f"\nSample of Predictions vs Actual Values:")
print("-" * 60)
print(f"{'Index':>8} | {'Actual':>12} | {'Predicted':>12} | {'Difference':>12}")
print("-" * 60)

n_samples = min(20, len(y_test_flat))
for i in range(n_samples):
    actual = y_test_flat[i]
    pred = y_pred_flat[i]
    diff = actual - pred
    print(f"{i:8d} | {actual:12.4f} | {pred:12.4f} | {diff:12.4f}")
# Out:
# [I 2025-04-01 22:36:15,688] A new study created in memory with name: no-name-dba5682a-622f-4d25-8240-e4c21c0cf572
# /tmp/ipykernel_1467461/1005556331.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-1)
# /home/pepechuy/.local/lib/python3.12/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ...

# %%
print("Length of test data:", len(test))
print("n_steps_in:", n_steps_in)
print("Available prediction points:", len(test) - n_steps_in)
# Out:
# Length of test data: 9
# n_steps_in: 6
# Available prediction points: 3

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Oscar David Jaramillo Zuluaga.
# </footer>
